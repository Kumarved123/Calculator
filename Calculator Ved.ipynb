# %%
import tkinter



expression = ""

def press(num): 
    global expression
    expression = expression + str(num) 
    equation.set(expression) 

    
def equalpress():
    try: 
  
        global expression 
    
        total = str(eval(expression)) 
  
        equation.set(total) 
    

    
    except: 
  
        equation.set(" error ") 
        expression = "" 
        
def clear(): 
        global expression 
        expression = "" 
        equation.set("") 
        

        
root = tkinter.Tk()

root.title('Calculator')


equation = StringVar()
expression_field = Entry(gui, textvariable=equation)
expression_field.grid(columnspan=4, ipadx=70) 
  
    equation.set('enter your expression')
  

#bottons Numaricals

button1 = tkinter.Button(root, width=5,height = 3, text = '1',command=lambda: press(1))
button2 = tkinter.Button(root, width=5,height = 3, text = '2',command=lambda: press(1))
button3 = tkinter.Button(root, width=5,height = 3, text = '3',command=lambda: press(1))
button4 = tkinter.Button(root, width=5,height = 3, text = '4',command=lambda: press(1))
button5 = tkinter.Button(root, width=5,height = 3, text = '5',command=lambda: press(1))
button6 = tkinter.Button(root, width=5,height = 3, text = '6',command=lambda: press(1))
button7 = tkinter.Button(root, width=5,height = 3, text = '7',command=lambda: press(1))
button8 = tkinter.Button(root, width=5,height = 3, text = '8',command=lambda: press(1))
button9 = tkinter.Button(root, width=5,height = 3, text = '9',command=lambda: press(1))
button0 = tkinter.Button(root, width=5,height = 3, text = '0',command=lambda: press(1))


button1.grid(row=2,column=1)
button2.grid(row=2,column=2)
button3.grid(row=2,column=3)
button4.grid(row=3,column=1)
button5.grid(row=3,column=2)
button6.grid(row=3,column=3)
button7.grid(row=4,column=1)
button8.grid(row=4,column=2)
button9.grid(row=4,column=3)
button0.grid(row=5,column=2)


#Button for Applications

add = tkinter.Button(root, width=5, height = 4, text = '+')
sub = tkinter.Button(root, width=5, height = 4, text = '-')
mul = tkinter.Button(root, width=5, height = 4, text = 'X')
div = tkinter.Button(root, width=5, height = 4, text = '/')
rot = tkinter.Button(root, width=5, height = 4, text = '^')
per = tkinter.Button(root, width=5, height = 4, text = '%')

add.grid(row=4,column=4)
sub.grid(row=4,column=5)
mul.grid(row=3,column=4)
div.grid(row=3,column=5)
rot.grid(row=2,column=4)
per.grid(row=2,column=5)

root.mainloop()
# Out:
#   File "<ipython-input-16-37a457dccf56>", line 45
#     equation.set('enter your expression')
#     ^
# IndentationError: unexpected indent

# %%
from tkinter import *


expression = "" 

def press(num): 
    global expression 


    expression = expression + str(num) 

 
    equation.set(expression) 


def equalpress(): 

    try: 

        global expression 


        total = str(eval(expression)) 

        equation.set(total) 

        expression = "" 

 
    except: 

        equation.set(" error ") 
        expression = "" 

        
def clear(): 
    global expression 
    expression = "" 
    equation.set("") 


if __name__ == "__main__": 

    gui = Tk() 


    gui.title("Simple Calculator") 


    equation = StringVar() 

 
    expression_field = Entry(gui, textvariable=equation) 

 
    expression_field.grid(columnspan=8, ipadx=70) 

    equation.set('enter your expression') 

    button1 = Button(gui, text=' 1 ', command=lambda: press(1), height=3, width=7) 
    button1.grid(row=2, column=0) 

    button2 = Button(gui, text=' 2 ', command=lambda: press(2), height=3, width=7) 
    button2.grid(row=2, column=1) 

    button3 = Button(gui, text=' 3 ', command=lambda: press(3), height=3, width=7) 
    button3.grid(row=2, column=2) 

    button4 = Button(gui, text=' 4 ', command=lambda: press(4), height=3, width=7) 
    button4.grid(row=3, column=0) 

    button5 = Button(gui, text=' 5 ', command=lambda: press(5), height=3, width=7) 
    button5.grid(row=3, column=1) 

    button6 = Button(gui, text=' 6 ', command=lambda: press(6), height=3, width=7) 
    button6.grid(row=3, column=2) 

    button7 = Button(gui, text=' 7 ', command=lambda: press(7), height=3, width=7) 
    button7.grid(row=4, column=0) 

    button8 = Button(gui, text=' 8 ', command=lambda: press(8), height=3, width=7) 
    button8.grid(row=4, column=1) 

    button9 = Button(gui, text=' 9 ', command=lambda: press(9), height=3, width=7) 
    button9.grid(row=4, column=2) 

    button0 = Button(gui, text=' 0 ', command=lambda: press(0), height=3, width=7) 
    button0.grid(row=5, column=0) 

    plus = Button(gui, text=' + ',    command=lambda: press("+"), height=4, width=7) 
    plus.grid(row=2, column=3) 

    minus = Button(gui, text=' - ', command=lambda: press("-"), height=4, width=7) 
    minus.grid(row=3, column=3) 

    multiply = Button(gui, text=' * ', command=lambda: press("*"), height=4, width=7) 
    multiply.grid(row=4, column=3) 

    divide = Button(gui, text=' / ', command=lambda: press("/"), height=4, width=7) 
    divide.grid(row=5, column=3) 

    plus = Button(gui, text=' ^',    command=lambda: press("^"), height=4, width=7) 
    plus.grid(row=2, column=4) 

    minus = Button(gui, text=' %', command=lambda: press("%"), height=4, width=7) 
    minus.grid(row=3, column=4) 

    multiply = Button(gui, text=' 00', command=lambda: press("00"), height=4, width=7) 
    multiply.grid(row=4, column=4) 

    divide = Button(gui, text=' &', command=lambda: press("&"), height=4, width=7) 
    divide.grid(row=5, column=4) 
    equal = Button(gui, text=' = ', command=equalpress, height=4, width=7) 
    equal.grid(row=5, column=2) 

    clear = Button(gui, text='Clear', command=clear, height=4, width=7) 
    clear.grid(row=5, column='1') 


    gui.mainloop()
